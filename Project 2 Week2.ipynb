# %%
import numpy as np
from numpy import fliplr, flipud
import pandas as pd
from skimage.io import imread, imshow
from skimage import util
from PIL import Image
import skimage.color

# %%
print("**Welcome to Image Editor**")
print(" ")
print("Select from below options:")
count = 0
while(1):
    inp = int(input("1. Load Image  \n2. Edit image \n3. Save Image \n4. Quit \n5.Show image\n"))
    if inp==1:
        #inp1 = input("Enter image url: (Pro tip👽 Try entering: cook.jpg, other you might face an error🥹)")
        cook = io.imread('cook.jpg')
        print("Image loading---\n-----Wait a sec👀")
        #imshow(cook)
        print("image loaded")
        count+=1

    elif inp==2:
        print("Choose from the options below:")
        inp2 = int(input("1. Horizontal Flip \n2. Vertical Flip \n3. Invert colors\n4. Convert to Grayscale\n5. Convert to B&W\n"))

        if count>0:    
            if inp2==1:
                cook = fliplr(cook)
            elif inp2==2:
                cook = flipud(cook)
            elif inp2==3:
                cook = util.invert(cook)
            elif inp2==4:
                cook = skimage.color.rgb2gray(cook)
            elif inp2==5:
                cook = skimage.color.rgb2gray(cook)
            else:
                print("Enter a valid choice!!")
        else:
            print("Load an image first!!🤦🏻‍♀️")
            continue
    elif inp==3:
        print("Image saved")
    elif inp==4:
        break
    elif inp==5:
        imshow(cook)
    else:
        print("Enter a valid choice!!😵")
# Out:
# **Welcome to Image Editor**
#
# Select from below options:
# 1. Load Image
# 2. Edit image
# 3. Save Image
# 4. Quit
# 5.Show image
# 1
# Image loading---
# -----Wait a sec👀
# image loaded
# 1. Load Image
# 2. Edit image
# 3. Save Image
# 4. Quit
# 5.Show image
# 2
# Choose from the options below:
# 1. Horizontal Flip
# 2. Vertical Flip
# 3. Invert colors
# 4. Convert to Grayscale
# 5. Convert to B&W
# 1
# 1. Load Image
# 2. Edit image
# 3. Save Image
# 4. Quit
# 5.Show image
# 2
# Choose from the options below:
# 1. Horizontal Flip
# 2. Vertical Flip
# 3. Invert colors
# 4. Convert to Grayscale
# 5. Convert to B&W
# 2
# 1. Load Image
# 2. Edit image
# 3. Save Image
# 4. Quit
# 5.Show image
# 2
# Choose from the options below:
# 1. Horizontal Flip
# 2. Vertical Flip
# 3. Invert colors
# 4. Convert to Grayscale
# 5. Convert to B&W
# 4
# 1. Load Image
# 2. Edit image
# 3. Save Image
# 4. Quit
# 5.Show image
# 5
# 1. Load Image
# 2. Edit image
# 3. Save Image
# 4. Quit
# 5.Show image
# ...
